# %% [markdown]
# Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Loading dataset

# %%
df=pd.read_csv('Happiness report.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
df.shape
# Out:
# (158, 12)

# %% [markdown]
# # Checking null values

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
import seaborn as sns
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# There are no null values present in the dataset

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df['Region'].value_counts()
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %% [markdown]
# # Univariate Analysis

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
sns.distplot(df['Standard Error'])
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Density'>

# %%
sns.distplot(df['Economy (GDP per Capita)'])
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Density'>

# %%
sns.distplot(df['Health (Life Expectancy)'])
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Density'>

# %%
sns.distplot(df['Freedom'])
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Density'>

# %%
sns.distplot(df['Economy (GDP per Capita)'])
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Density'>

# %%
sns.distplot(df['Generosity'])
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Density'>

# %%
sns.distplot(df['Dystopia Residual'])
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Density'>

# %% [markdown]
# # Bivariate Analysis

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(20,5))
plt.title('Regionwise Happiness Score')
sns.barplot(df['Region'],df['Happiness Score'],label='Happiness Score')
plt.show()

# %% [markdown]
# Observations: Region which having less number of countries have high happiness score.

# %%
for i in df.columns:
    plt.figure(figsize=(15,5))
    sns.scatterplot(df[i],df['Happiness Score'],label='Happiness Score')
    plt.title(i)
    plt.show()

# %% [raw]
# Observation from Bivatriate Analysis:
#
# 1.Happiness Rank and country column can be removed from the data as it is completely not related to calculate the Happiness score

# %%
df.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True,linewidths=0.5,linecolor="black",)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observations: Happiness rank is making highly negative correlation with happiness ranks

# %% [markdown]
# # Feature Selection

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
col=['Country','Happiness Rank','Standard Error','Region']
df=df.drop(col,axis=1)

# %%
df.head()
# Out:
#    Happiness Score  Economy (GDP per Capita)   Family  \
# 0            7.587                   1.39651  1.34951
# 1            7.561                   1.30232  1.40223
# 2            7.527                   1.32548  1.36058
# 3            7.522                   1.45900  1.33095
# 4            7.427                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
df.shape
# Out:
# (158, 8)

# %% [markdown]
# # Outliers removal

# %%
collist=df.columns.values
ncol=30
nrows=14

# %%
collist
# Out:
# array(['Happiness Score', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom',
#        'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual'],
#       dtype=object)

# %% [markdown]
# Importing Box plot to detect outliers

# %%
plt.figure(figsize=(ncol,8*nrows))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(data=df[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([ 27, 128, 147, 153, 155, 157], dtype=int64),
#  array([5, 6, 2, 5, 7, 2], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 0              7.587                   1.39651  1.34951
# 1              7.561                   1.30232  1.40223
# 2              7.527                   1.32548  1.36058
# 3              7.522                   1.45900  1.33095
# 4              7.427                   1.32629  1.32261
# ..               ...                       ...      ...
# 150            3.655                   0.46534  0.77115
# 151            3.587                   0.25812  0.85188
# 152            3.575                   0.31982  0.30285
# 154            3.340                   0.28665  0.35386
# 156            2.905                   0.01530  0.41587
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# ...

# %%
df.shape
# Out:
# (158, 8)

# %%
df_new.shape
# Out:
# (152, 8)

# %%
print("Old Dataframe",df.shape)
print("New Dataframe",df_new.shape)
print("total_dropped_rows",df.shape[0]-df_new.shape[0])
# Out:
# Old Dataframe (158, 8)
# New Dataframe (152, 8)
# total_dropped_rows 6

# %%
loss_percent=(158-152)/158*100
print(loss_percent,'%')
# Out:
# 3.79746835443038 %

# %%
df=df_new.copy()

# %%
df
# Out:
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 0              7.587                   1.39651  1.34951
# 1              7.561                   1.30232  1.40223
# 2              7.527                   1.32548  1.36058
# 3              7.522                   1.45900  1.33095
# 4              7.427                   1.32629  1.32261
# ..               ...                       ...      ...
# 150            3.655                   0.46534  0.77115
# 151            3.587                   0.25812  0.85188
# 152            3.575                   0.31982  0.30285
# 154            3.340                   0.28665  0.35386
# 156            2.905                   0.01530  0.41587
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# ...

# %%
df.shape
# Out:
# (152, 8)

# %% [markdown]
# # Splitting the data for training and testing

# %%
x=df.iloc[:,1:]
x
# Out:
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# 3                     1.45900  1.33095                   0.88521  0.66973
# 4                     1.32629  1.32261                   0.90563  0.63297
# ..                        ...      ...                       ...      ...
# 150                   0.46534  0.77115                   0.15185  0.46866
# 151                   0.25812  0.85188                   0.27125  0.39493
# 152                   0.31982  0.30285                   0.30335  0.23414
# 154                   0.28665  0.35386                   0.31910  0.48450
# 156                   0.01530  0.41587                   0.22396  0.11850
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# ...

# %%
x.shape
# Out:
# (152, 7)

# %%
y=df.iloc[:,0:1]
y
# Out:
#      Happiness Score
# 0              7.587
# 1              7.561
# 2              7.527
# 3              7.522
# 4              7.427
# ..               ...
# 150            3.655
# 151            3.587
# 152            3.575
# 154            3.340
# 156            2.905
#
# [152 rows x 1 columns]

# %%
y.shape
# Out:
# (152, 1)

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.2)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f"At random state{i},the training accuracy is: {r2_score(y_train,pred_train)}")
    print(f"At random state{i},the testing accuracy is: {r2_score(y_test,pred_test)}")
    print("\n")
# Out:
# At random state0,the training accuracy is: 0.9999999401994266
# At random state0,the testing accuracy is: 0.9999999105856291
#
#
# At random state1,the training accuracy is: 0.9999999422782792
# At random state1,the testing accuracy is: 0.9999998925450942
#
#
# At random state2,the training accuracy is: 0.9999999366800707
# At random state2,the testing accuracy is: 0.9999999196193731
#
#
# At random state3,the training accuracy is: 0.9999999382657543
# At random state3,the testing accuracy is: 0.9999999211135586
#
#
# At random state4,the training accuracy is: 0.9999999355748581
# At random state4,the testing accuracy is: 0.999999918554076
#
#
# At random state5,the training accuracy is: 0.9999999439237856
# At random state5,the testing accuracy is: 0.9999998925133334
#
#
# At random state6,the training accuracy is: 0.9999999431580001
# At random state6,the testing accuracy is: 0.9999998964547809
#
#
# At random state7,the training accuracy is: 0.9999999389196892
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=1,test_size=0.20)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_train=lr.predict(x_train)

# %%
pred_test=lr.predict(x_test)

# %%
r2_score(y_train,pred_train)
# Out:
# 0.9999999422782792

# %%
r2_score(y_test,pred_test)
# Out:
# 0.9999998925450942

# %% [markdown]
# # Cross Validation of the model

# %%
Train_accuracy=r2_score(y_train,pred_train)
Test_accuracy=r2_score(y_test,pred_test)

# %%
from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=j)
    cv_mean=cv_score.mean()
    print("At cv:-",j)
    print(f"At cross fold {j} the cv score is {cv_mean} and accuracy score for training is {Train_accuracy} and accuracy score for testing is {Test_accuracy}")  
    print("\n")
# Out:
# At cv:- 2
# At cross fold 2 the cv score is 0.999999722557913 and accuracy score for training is 0.9999999422782792 and accuracy score for testing is 0.9999998925450942
#
#
# At cv:- 3
# At cross fold 3 the cv score is 0.999999468361971 and accuracy score for training is 0.9999999422782792 and accuracy score for testing is 0.9999998925450942
#
#
# At cv:- 4
# At cross fold 4 the cv score is 0.9999987556096168 and accuracy score for training is 0.9999999422782792 and accuracy score for testing is 0.9999998925450942
#
#
# At cv:- 5
# At cross fold 5 the cv score is 0.9999979441239665 and accuracy score for training is 0.9999999422782792 and accuracy score for testing is 0.9999998925450942
#
#
# At cv:- 6
# At cross fold 6 the cv score is 0.9999970173842118 and accuracy score for training is 0.9999999422782792 and accuracy score for testing is 0.9999998925450942
#
#
# At cv:- 7
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,4))
plt.scatter(x=y_test,y=pred_test,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('Acutal charges',fontsize=14)
plt.ylabel('Predicted charges',fontsize=18)
plt.title('LinearRegression',fontsize=18)
plt.savefig('lr.png')
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso
parameters={'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 0.0001, 'random_state': 0}

# %%
ls=Lasso(alpha=0.0001,random_state=0)
ls.fit(x_train,y_train)
ls_score_training=ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
print('score of the training models',ls_score_training*100)
# Out:
# score of the training models 99.99989281656313

# %%
pred_ls=ls.predict(x_test)

# %%
lss=r2_score(y_test,pred_ls)
print('r2 score of the model is',lss*100)
# Out:
# r2 score of the model is 99.99979823690221

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
print("error:")
print('Mean absolute error:', mean_absolute_error(y_test,pred_ls))
print('Mean squared error:', mean_squared_error(y_test,pred_ls))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred_ls)))
# Out:
# error:
# Mean absolute error: 0.000993158789122224
# Mean squared error: 1.722861571129603e-06
# Root Mean Squared Error: 0.0013125782152426586

# %%
## Root Mean Squared error is 0.001312. The value is almost negligible and the model is performing well.

# %% [markdown]
# # Saving the model

# %%
pred_ls
# Out:
# array([5.77048188, 6.41091925, 5.47700477, 4.29576694, 6.47727344,
#        4.69370802, 4.87425676, 7.11886878, 5.84826785, 5.98725267,
#        3.65571018, 3.93046008, 5.21281226, 4.80117002, 7.40388261,
#        5.1241642 , 6.9447368 , 4.85984901, 5.05336271, 4.89799928,
#        5.00774804, 4.36833229, 4.97050414, 4.86885859, 4.9602139 ,
#        6.1304317 , 6.50636338, 6.00079844, 5.83470398, 4.43533716,
#        6.30116434])

# %%
pred=pd.DataFrame(pred_ls)
pred=pred.rename(columns={0:'Predicted_Happiness Score'})

# %%
pred.head()
# Out:
#    Predicted_Happiness Score
# 0                   5.770482
# 1                   6.410919
# 2                   5.477005
# 3                   4.295767
# 4                   6.477273
