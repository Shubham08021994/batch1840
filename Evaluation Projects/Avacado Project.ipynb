# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Importing the entire avacado dataset on this jupyter notebook with the help of pandas

# %%
df=pd.read_csv('avacado.csv',sep='\t')
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1               1  20-12-2015          1.35      54876.98   674.28   44638.81
# 2               2  13-12-2015          0.93     118220.22   794.70  109149.67
# 3               3  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4               4  29-11-2015          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  04-02-2018          1.63      17074.83  2046.96    1529.20
# 18245           8  28-01-2018          1.71      13888.04  1191.70    3431.50
# 18246           9  21-01-2018          1.87      13766.76  1191.92    2452.79
# 18247          10  14-01-2018          1.93      16205.22  1527.63    2981.04
# 18248          11  07-01-2018          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1           1  20-12-2015          1.35      54876.98   674.28   44638.81
# 2           2  13-12-2015          0.93     118220.22   794.70  109149.67
# 3           3  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4           4  29-11-2015          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7  04-02-2018          1.63      17074.83  2046.96  1529.20
# 18245           8  28-01-2018          1.71      13888.04  1191.70  3431.50
# 18246           9  21-01-2018          1.87      13766.76  1191.92  2452.79
# 18247          10  14-01-2018          1.93      16205.22  1527.63  2981.04
# 18248          11  07-01-2018          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# ...

# %% [markdown]
# No. of rows --> 14
#
# No. of columns --> 18249
#
# Average price --> Dependent feature/Target column
#
# All the remaining 13 columns --> Independent features

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %% [markdown]
# checking different columns available in the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
object_datatype = []
for x in df.dtypes.index:
    if df.dtypes[x] == 'object':
        object_datatype.append(x)
object_datatype
# Out:
# ['Date', 'type', 'region']

# %%
integer_datatype = []
for x in df.dtypes.index:
    if df.dtypes[x] == 'int64':
        integer_datatype.append(x)
integer_datatype
# Out:
# ['Unnamed: 0', 'year']

# %%
float_datatype = []
for x in df.dtypes.index:
    if df.dtypes[x] == 'float64':
        float_datatype.append(x)
float_datatype
# Out:
# ['AveragePrice',
#  'Total Volume',
#  '4046',
#  '4225',
#  '4770',
#  'Total Bags',
#  'Small Bags',
#  'Large Bags',
#  'XLarge Bags']

# %% [markdown]
# # Checking Missing Values

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.nunique()
# Out:
# Unnamed: 0         53
# Date              169
# AveragePrice      259
# Total Volume    18237
# 4046            17702
# 4225            18103
# 4770            12071
# Total Bags      18097
# Small Bags      17321
# Large Bags      15082
# XLarge Bags      5588
# type                2
# year                4
# region             54
# dtype: int64

# %% [markdown]
# It is clear from the above that there are no null values are present in the dataset.

# %%
df.describe().T
# Out:
#                 count           mean           std      min       25%  \
# Unnamed: 0    18249.0      24.232232  1.548104e+01     0.00     10.00
# AveragePrice  18249.0       1.405978  4.026766e-01     0.44      1.10
# Total Volume  18249.0  850644.013009  3.453545e+06    84.56  10838.58
# 4046          18249.0  293008.424531  1.264989e+06     0.00    854.07
# 4225          18249.0  295154.568356  1.204120e+06     0.00   3008.78
# 4770          18249.0   22839.735993  1.074641e+05     0.00      0.00
# Total Bags    18249.0  239639.202060  9.862424e+05     0.00   5088.64
# Small Bags    18249.0  182194.686696  7.461785e+05     0.00   2849.42
# Large Bags    18249.0   54338.088145  2.439660e+05     0.00    127.47
# XLarge Bags   18249.0    3106.426507  1.769289e+04     0.00      0.00
# year          18249.0    2016.147899  9.399385e-01  2015.00   2015.00
#
#                     50%        75%          max
# Unnamed: 0        24.00      38.00        52.00
# ...

# %% [markdown]
# The feature "Unnamed:0" is just a representation of the indexes, lets remove it now !

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %% [markdown]
# Checking head again to make sure that the feature "Unnamed:0" is removed from the dataset

# %%
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  27-12-2015          1.33      64236.62  1036.74   54454.85   48.16
# 1  20-12-2015          1.35      54876.98   674.28   44638.81   58.33
# 2  13-12-2015          0.93     118220.22   794.70  109149.67  130.50
# 3  06-12-2015          1.08      78992.15  1132.00   71976.41   72.58
# 4  29-11-2015          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %% [markdown]
# Earlier in info it is observed that datatypes of date column is object type not date type. let change the dtype of date colummn.

# %%
df['Date']=pd.to_datetime(df['Date'])
df['Month']=df['Date'].apply(lambda x:x.month)
df['Day']=df['Date'].apply(lambda x:x.day)

# %% [markdown]
# Lets check the head again

# %%
df.head()
# Out:
#         Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3 2015-06-12          1.08      78992.15  1132.00   71976.41   72.58
# 4 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015
# 1     9505.56     9408.07       97.49          0.0  conventional  2015
# 2     8145.35     8042.21      103.14          0.0  conventional  2015
# 3     5811.16     5677.40      133.76          0.0  conventional  2015
# 4     6183.95     5986.26      197.69          0.0  conventional  2015
#
#    region  Month  Day
# 0  Albany     12   27
# 1  Albany     12   20
# 2  Albany     12   13
# 3  Albany      6   12
# ...

# %%
df.shape
# Out:
# (18249, 15)

# %% [markdown]
# # Visualization

# %%
sns.countplot(x='type',data=df)
# Out:
# <AxesSubplot:xlabel='type', ylabel='count'>

# %%
df['type'].value_counts()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %% [markdown]
# Almost equal number of conventional and organic avacados were produced

# %%
df.year.unique()
# Out:
# array([2015, 2016, 2017, 2018], dtype=int64)

# %%
sns.countplot(df.year)
# Out:
# <AxesSubplot:xlabel='year', ylabel='count'>

# %%
df['year'].value_counts()
# Out:
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: year, dtype: int64

# %% [markdown]
# for 2018 there is small amount of data available

# %%
df.region.nunique()
# Out:
# 54

# %%
plt.figure(figsize=(20,15))
sns.countplot(x='region',data=df,palette='turbo')
plt.xticks(rotation=90)
plt.show()

# %%
df['region'].value_counts()
# Out:
# Albany                 338
# Sacramento             338
# Northeast              338
# NorthernNewEngland     338
# Orlando                338
# Philadelphia           338
# PhoenixTucson          338
# Pittsburgh             338
# Plains                 338
# Portland               338
# RaleighGreensboro      338
# RichmondNorfolk        338
# Roanoke                338
# SanDiego               338
# Atlanta                338
# SanFrancisco           338
# Seattle                338
# SouthCarolina          338
# SouthCentral           338
# Southeast              338
# Spokane                338
# StLouis                338
# Syracuse               338
# Tampa                  338
# TotalUS                338
# West                   338
# NewYork                338
# NewOrleansMobile       338
# Nashville              338
# Midsouth               338
# BaltimoreWashington    338
# Boise                  338
# Boston                 338
# BuffaloRochester       338
# ...

# %%
# how much avacaddo sell per year

df.groupby('year')['type'].value_counts()
# Out:
# year  type
# 2015  conventional    2808
#       organic         2807
# 2016  conventional    2808
#       organic         2808
# 2017  conventional    2862
#       organic         2860
# 2018  conventional     648
#       organic          648
# Name: type, dtype: int64

# %% [markdown]
# Both type of avacado is present in almost same amount each year

# %%
sns.barplot(x='year',y='AveragePrice',data=df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='AveragePrice'>

# %% [markdown]
# It is observed that there was a spike in average price in the year 2017.As we have seen above, average price was more in 2017

# %%
# Year
df['year'].unique()
# Out:
# array([2015, 2016, 2017, 2018], dtype=int64)

# %%
plt.figure(figsize=(10,6))
sns.barplot(y='Total Volume',x='year', data=df)
plt.xlabel('Year',fontsize=25)
plt.ylabel('Total Volume',fontsize=25)
plt.show()

# %%
df.groupby('year')['Total Volume'].sum()
# Out:
# year
# 2015    4.385469e+09
# 2016    4.820890e+09
# 2017    4.934306e+09
# 2018    1.382738e+09
# Name: Total Volume, dtype: float64

# %% [markdown]
# Total avacado sales increases by year.

# %%
df['AveragePrice'].nunique()
# Out:
# 259

# %% [markdown]
# We have 3 varity of avacado,  Product Lookup Code  PLU
# 4046 , 4225 , 4770

# %%
# Find Average price by type of avacado

df.groupby('type')['AveragePrice'].sum()
# Out:
# type
# conventional    10568.27
# organic         15089.43
# Name: AveragePrice, dtype: float64

# %%
plt.figure(figsize=(6,4))
sns.barplot(y='AveragePrice',x='type', data=df)
plt.xlabel('Type',fontsize=18)
plt.ylabel('AveragePrice',fontsize=18)
plt.show()

# %% [markdown]
# Organic avacado have high average price than conventional

# %%
# Which type sold more, if price have any impact on sold

df.groupby('type')['Total Volume'].sum()
# Out:
# type
# conventional    1.508722e+10
# organic         4.361817e+08
# Name: Total Volume, dtype: float64

# %%
plt.figure(figsize=(6,4))
sns.barplot(y='Total Volume',x='type', data=df)
plt.xlabel('Type',fontsize=18)
plt.ylabel('Total Volume',fontsize=18)
plt.show()

# %% [markdown]
# Conventional avacdo have more sale than organic

# %%
# Total sale by year by type
sns.barplot(y='Total Volume',x='year',hue='type', data=df)
plt.xlabel('year',fontsize=18)
plt.ylabel('Total Volume',fontsize=18)
plt.show()

# %% [markdown]
# Sales of avacado increased by year

# %%
plt.figure(figsize=(15,10))
sns.catplot(x="type", y="Total Bags", hue="year", data=df, kind="bar")
plt.xlabel('Type',fontsize=18)
plt.ylabel('Total Bags',fontsize=18)
plt.show()

# %% [markdown]
# This show that Total Bags of conventional type has always been higher than organic type

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnum=1
y = df[['4046','4225','4770']]
X = df['type']
for col in y:
    if plotnum<=23:
        plt.subplot(5,5,plotnum)
        sns.barplot(X,y[col])
        plt.xlabel('type',fontsize=20)
        plt.ylabel(col,fontsize=20)
    plotnum+=1
plt.tight_layout()

# %% [markdown]
# Production of conventional type outnumbers that of organic type in the cases of 4046,4225 and 4770, which may also be a contributing factor to the higher average price of organic type

# %%
df['4046'].sum()
# Out:
# 5347110739.26

# %%
df['4225'].sum()
# Out:
# 5386275717.93

# %%
df['4770'].sum()
# Out:
# 416802342.12999994

# %% [markdown]
# Type  4225  sold mostly, then 4046..  type 4770 is very less

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnum=1
y = df[['4046','4225','4770']]
X = df['year']
for col in y:
    if plotnum<=23:
        plt.subplot(5,5,plotnum)
        sns.barplot(X,y[col])
        plt.xlabel('Year',fontsize=20)
        plt.ylabel(col,fontsize=20)
    plotnum+=1
plt.tight_layout()

# %% [markdown]
# Production of PLU 4046 has grown over the 4 years and is greater than the production of PLU 4225 and PLU 4770, which is least produced

# %%
sns.barplot(x='Month',y='AveragePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Month', ylabel='AveragePrice'>

# %%
df.groupby('Month')['AveragePrice'].mean().sort_values()
# Out:
# Month
# 1     1.337533
# 12    1.345754
# 3     1.348275
# 5     1.368784
# 2     1.372244
# 4     1.384101
# 11    1.411204
# 6     1.425375
# 7     1.436318
# 8     1.468204
# 10    1.486700
# 9     1.539091
# Name: AveragePrice, dtype: float64

# %%
plt.figure(figsize=(10,3))
sns.lineplot('Month','AveragePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Month', ylabel='AveragePrice'>

# %% [markdown]
# Average price was high in July, august,sept,October months

# %%
plt.figure(figsize=(10,3))
sns.lineplot('Month','AveragePrice',hue='type',data=df)
# Out:
# <AxesSubplot:xlabel='Month', ylabel='AveragePrice'>

# %% [markdown]
# Conclusion:  Price hike for both type of avacado during 8,9,10 months

# %% [markdown]
# Jan-FEB-March  is the season for avacado, so price is comapritvely low
# in DEC, every one wants to clear stock for new year production , so price came down

# %%
g = sns.factorplot('AveragePrice','region',data=df,
                   hue='year',
                   size=18,
                   aspect=0.7,
                   palette='Blues',
                   join=False,
              )

# %% [markdown]
# Looks like there was a huge increase in Avocado prices as the demand was little high in Year 2017 in SanFranciso region.

# %%
df.hist(figsize=(15,15), bins=25)
# Out:
# array([[<AxesSubplot:title={'center':'Date'}>,
#         <AxesSubplot:title={'center':'AveragePrice'}>,
#         <AxesSubplot:title={'center':'Total Volume'}>,
#         <AxesSubplot:title={'center':'4046'}>],
#        [<AxesSubplot:title={'center':'4225'}>,
#         <AxesSubplot:title={'center':'4770'}>,
#         <AxesSubplot:title={'center':'Total Bags'}>,
#         <AxesSubplot:title={'center':'Small Bags'}>],
#        [<AxesSubplot:title={'center':'Large Bags'}>,
#         <AxesSubplot:title={'center':'XLarge Bags'}>,
#         <AxesSubplot:title={'center':'year'}>,
#         <AxesSubplot:title={'center':'Month'}>],
#        [<AxesSubplot:title={'center':'Day'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %% [markdown]
# AveragePrice is almost normally distributed
#
# other columns are right skewed

# %% [markdown]
# # Encoding the categorical object datatype columns

# %%
df.dtypes
# Out:
# Date            datetime64[ns]
# AveragePrice           float64
# Total Volume           float64
# 4046                   float64
# 4225                   float64
# 4770                   float64
# Total Bags             float64
# Small Bags             float64
# Large Bags             float64
# XLarge Bags            float64
# type                    object
# year                     int64
# region                  object
# Month                    int64
# Day                      int64
# dtype: object

# %%
import sklearn
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df["type"] = le.fit_transform(df["type"])
df["region"] = le.fit_transform(df["region"])
df.head()
# Out:
#         Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3 2015-06-12          1.08      78992.15  1132.00   71976.41   72.58
# 4 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags  type  year  region  Month  \
# 0     8696.87     8603.62       93.25          0.0     0  2015       0     12
# 1     9505.56     9408.07       97.49          0.0     0  2015       0     12
# 2     8145.35     8042.21      103.14          0.0     0  2015       0     12
# 3     5811.16     5677.40      133.76          0.0     0  2015       0      6
# 4     6183.95     5986.26      197.69          0.0     0  2015       0     11
#
#    Day
# 0   27
# 1   20
# 2   13
# 3   12
# 4   29

# %%
df.dtypes
# Out:
# Date            datetime64[ns]
# AveragePrice           float64
# Total Volume           float64
# 4046                   float64
# 4225                   float64
# 4770                   float64
# Total Bags             float64
# Small Bags             float64
# Large Bags             float64
# XLarge Bags            float64
# type                     int32
# year                     int64
# region                   int32
# Month                    int64
# Day                      int64
# dtype: object

# %% [markdown]
# All the object/categorical datatypes converted into int type

# %%
df.hist(figsize=(25,30))
plt.show()

# %% [markdown]
# Using the above histogram we are able to plot all the columns of are dataset post application of encoding technique where we do not have any object datatype columns anymore.

# %% [markdown]
# # Correlation

# %%
df.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.192752 -0.208317 -0.172928 -0.179446
# Total Volume     -0.192752      1.000000  0.977863  0.974181  0.872202
# 4046             -0.208317      0.977863  1.000000  0.926110  0.833389
# 4225             -0.172928      0.974181  0.926110  1.000000  0.887855
# 4770             -0.179446      0.872202  0.833389  0.887855  1.000000
# Total Bags       -0.177088      0.963047  0.920057  0.905787  0.792314
# Small Bags       -0.174730      0.967238  0.925280  0.916031  0.802733
# Large Bags       -0.172940      0.880640  0.838645  0.810015  0.698471
# XLarge Bags      -0.117592      0.747157  0.699377  0.688809  0.679861
# type              0.615845     -0.232434 -0.225819 -0.232289 -0.210027
# year              0.093197      0.017193  0.003353 -0.009559 -0.036531
# region           -0.011716      0.174176  0.192073  0.145726  0.095252
# ...

# %%
# visualization of correlation relationships
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True,cmap="BuPu")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# As heatmap of correlation of our dataset df is displaying that many of columns are highly correleted to each other means columns like, 4046,4225,4770 are highly correlated with Total Volume in this case we have to drop these columns ,similarly small Bags,Large Bags and Xlarge Bags are highly correleted with Totla Bags these columns also needs to be dropped in order to secure from multicollearnity problems

# %%
plt.figure(figsize = (20,8))
df.corr()['AveragePrice'].sort_values(ascending = False).drop(['AveragePrice']).plot(kind='bar',color = 'c')
plt.xlabel('Features',fontsize=15)
plt.ylabel('AveragePrice',fontsize=15)
plt.title('correlation',fontsize = 18)
plt.show()

# %% [markdown]
# 'type_organic' has the highest positive correlation with 'AveragePrice', 'type_conventional' has the highest negative correlation while 'region' has the weakest correlation.

# %% [markdown]
# # Dropping 'Date' column since it doesn't contribute to building a good model for predicting the target variable values

# %%
df.drop(columns=['Date','Total Volume','Total Bags' ],inplace = True)

# %%
df
# Out:
#        AveragePrice     4046       4225    4770  Small Bags  Large Bags  \
# 0              1.33  1036.74   54454.85   48.16     8603.62       93.25
# 1              1.35   674.28   44638.81   58.33     9408.07       97.49
# 2              0.93   794.70  109149.67  130.50     8042.21      103.14
# 3              1.08  1132.00   71976.41   72.58     5677.40      133.76
# 4              1.28   941.48   43838.39   75.78     5986.26      197.69
# ...             ...      ...        ...     ...         ...         ...
# 18244          1.63  2046.96    1529.20    0.00    13066.82      431.85
# 18245          1.71  1191.70    3431.50    0.00     8940.04      324.80
# 18246          1.87  1191.92    2452.79  727.94     9351.80       42.31
# 18247          1.93  1527.63    2981.04  727.01    10919.54       50.00
# 18248          1.62  2894.77    2356.13  224.53    11988.14       26.01
#
#        XLarge Bags  type  year  region  Month  Day
# 0              0.0     0  2015       0     12   27
# ...

# %% [markdown]
# # Checking for Outliers

# %%
df.plot(kind='box', subplots=True, layout=(4,5),figsize=(15,10))
# Out:
# AveragePrice        AxesSubplot(0.125,0.71587;0.133621x0.16413)
# 4046             AxesSubplot(0.285345,0.71587;0.133621x0.16413)
# 4225              AxesSubplot(0.44569,0.71587;0.133621x0.16413)
# 4770             AxesSubplot(0.606034,0.71587;0.133621x0.16413)
# Small Bags       AxesSubplot(0.766379,0.71587;0.133621x0.16413)
# Large Bags         AxesSubplot(0.125,0.518913;0.133621x0.16413)
# XLarge Bags     AxesSubplot(0.285345,0.518913;0.133621x0.16413)
# type             AxesSubplot(0.44569,0.518913;0.133621x0.16413)
# year            AxesSubplot(0.606034,0.518913;0.133621x0.16413)
# region          AxesSubplot(0.766379,0.518913;0.133621x0.16413)
# Month              AxesSubplot(0.125,0.321957;0.133621x0.16413)
# Day             AxesSubplot(0.285345,0.321957;0.133621x0.16413)
# dtype: object

# %% [markdown]
# There are outliers present in the features

# %% [markdown]
# # Using Z Score to remove outliers

# %%
from scipy.stats import zscore

# %%
z = np.abs(zscore(df))
threshold = 3
df1 = df[(z<3).all(axis = 1)]
df1
# Out:
#        AveragePrice     4046       4225    4770  Small Bags  Large Bags  \
# 0              1.33  1036.74   54454.85   48.16     8603.62       93.25
# 1              1.35   674.28   44638.81   58.33     9408.07       97.49
# 2              0.93   794.70  109149.67  130.50     8042.21      103.14
# 3              1.08  1132.00   71976.41   72.58     5677.40      133.76
# 4              1.28   941.48   43838.39   75.78     5986.26      197.69
# ...             ...      ...        ...     ...         ...         ...
# 18244          1.63  2046.96    1529.20    0.00    13066.82      431.85
# 18245          1.71  1191.70    3431.50    0.00     8940.04      324.80
# 18246          1.87  1191.92    2452.79  727.94     9351.80       42.31
# 18247          1.93  1527.63    2981.04  727.01    10919.54       50.00
# 18248          1.62  2894.77    2356.13  224.53    11988.14       26.01
#
#        XLarge Bags  type  year  region  Month  Day
# 0              0.0     0  2015       0     12   27
# ...

# %%
print ("Shape of the dataframe before removing outliers: ", df.shape)
print ("Shape of the dataframe after removing outliers: ", df1.shape)
print ("Percentage of data loss post outlier removal: ", (df.shape[0]-df1.shape[0])/df.shape[0]*100)

df=df1.copy() # reassigning the changed dataframe name to our original dataframe name
# Out:
# Shape of the dataframe before removing outliers:  (18249, 12)
# Shape of the dataframe after removing outliers:  (17651, 12)
# Percentage of data loss post outlier removal:  3.276891884486821

# %%
df.plot(kind='box', subplots=True, layout=(4,5),figsize=(15,10))
# Out:
# AveragePrice        AxesSubplot(0.125,0.71587;0.133621x0.16413)
# 4046             AxesSubplot(0.285345,0.71587;0.133621x0.16413)
# 4225              AxesSubplot(0.44569,0.71587;0.133621x0.16413)
# 4770             AxesSubplot(0.606034,0.71587;0.133621x0.16413)
# Small Bags       AxesSubplot(0.766379,0.71587;0.133621x0.16413)
# Large Bags         AxesSubplot(0.125,0.518913;0.133621x0.16413)
# XLarge Bags     AxesSubplot(0.285345,0.518913;0.133621x0.16413)
# type             AxesSubplot(0.44569,0.518913;0.133621x0.16413)
# year            AxesSubplot(0.606034,0.518913;0.133621x0.16413)
# region          AxesSubplot(0.766379,0.518913;0.133621x0.16413)
# Month              AxesSubplot(0.125,0.321957;0.133621x0.16413)
# Day             AxesSubplot(0.285345,0.321957;0.133621x0.16413)
# dtype: object

# %% [markdown]
# # VIF to check multicolinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def vif_calc():
    vif=pd.DataFrame()
    vif['VIF Factor']=[variance_inflation_factor(X.values,i) for i in range(X.shape[1])]
    vif['features']=X.columns
    print(vif)

# %%
vif_calc()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3324/2667789658.py in <module>
# ----> 1 vif_calc()
#
# ~\AppData\Local\Temp/ipykernel_3324/2690094972.py in vif_calc()
#       1 def vif_calc():
#       2     vif=pd.DataFrame()
# ----> 3     vif['VIF Factor']=[variance_inflation_factor(X.values,i) for i in range(X.shape[1])]
#       4     vif['features']=X.columns
#       5     print(vif)
#
# IndexError: tuple index out of range

# %% [markdown]
# No multicollinearity

# %% [markdown]
# # Checking Skewness

# %%
df.skew()
# Out:
# AveragePrice    0.377432
# 4046            4.909848
# 4225            4.455745
# 4770            5.117170
# Small Bags      4.222706
# Large Bags      5.053434
# XLarge Bags     6.135607
# type           -0.037741
# year            0.229976
# region          0.012798
# Month           0.046419
# Day            -0.005030
# dtype: float64

# %% [markdown]
# With the skew method we see that there are columns present in our dataset that are above the acceptable range of +/-0.5 value

# %% [markdown]
# # Using Log Transform to fix skewness

# %%
for col in df:
    if df.skew().loc[col]>0.5:
        df[col]=np.log1p(df[col])

# %%
fig, ax = plt.subplots(ncols=3, nrows=4, figsize=(20,15))
index = 0
ax = ax.flatten()
for col, value in df.items():
    sns.distplot(value, ax=ax[index], hist=False, color="r", kde_kws={"shade": True})
    index += 1
plt.show()

# %%
df.skew()
# Out:
# AveragePrice    0.377432
# 4046           -0.420273
# 4225           -0.604619
# 4770            0.068532
# Small Bags     -0.788988
# Large Bags     -0.610874
# XLarge Bags     1.216238
# type           -0.037741
# year            0.229976
# region          0.012798
# Month           0.046419
# Day            -0.005030
# dtype: float64

# %% [markdown]
# Skewness has been reduced significantly

# %% [markdown]
# # Splitting the dataset into 2 variables namely 'X' and 'Y' for feature and label

# %%
X = df.drop('AveragePrice', axis=1)
Y = df['AveragePrice']

# %%
X.shape
# Out:
# (17651, 11)

# %%
Y.shape
# Out:
# (17651,)

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
X.head()
# Out:
#        4046      4225      4770  Small Bags  Large Bags  XLarge Bags  \
# 0 -0.587318  0.431565 -0.246207   -0.215789   -0.648254    -0.627319
# 1 -0.719464  0.359601 -0.199437   -0.179590   -0.636520    -0.627319
# 2 -0.668997  0.683316 -0.001478   -0.243116   -0.621646    -0.627319
# 3 -0.560308  0.532565 -0.145897   -0.384129   -0.552915    -0.627319
# 4 -0.616931  0.353051 -0.135308   -0.362677   -0.449388    -0.627319
#
#        type      year    region     Month       Day
# 0 -1.019047 -1.210013 -1.695495  1.593046  1.280854
# 1 -1.019047 -1.210013 -1.695495  1.593046  0.502214
# 2 -1.019047 -1.210013 -1.695495  1.593046 -0.276425
# 3 -1.019047 -1.210013 -1.695495 -0.107314 -0.387659
# 4 -1.019047 -1.210013 -1.695495  1.309653  1.503322

# %% [markdown]
# I am scaling my feature data to ensure that there is no issue with the data biasness over a particular column instead a standardization will occur helping us in having a uniform dataset values

# %% [markdown]
# # Creating the training and testing data sets

# %%
# Its a Regression problem coz output variable have continuous data, Average Price
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

LR= LinearRegression()

# %%
# Train Test Split / finding best random_state for my model

for i in range(0,200):
    x_train,x_test,y_train,y_test= train_test_split(X,Y,random_state=i,test_size=.3)
    LR.fit(x_train,y_train)
    train_pred=LR.predict(x_train)
    test_pred=LR.predict(x_test)
    if round(r2_score(y_test,test_pred),2)==round(r2_score(y_train,train_pred),2):
        print("At random state ", i, "The model performance very well")
        print("At random state: ",i)
        print("Test R2 score is: ", round(r2_score(y_test,test_pred),2))
        print('Train R2 score is: ', round(r2_score(y_train,train_pred),2))
        print('X'*50,'\n')
# Out:
# At random state  1 The model performance very well
# At random state:  1
# Test R2 score is:  0.48
# Train R2 score is:  0.48
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  4 The model performance very well
# At random state:  4
# Test R2 score is:  0.48
# Train R2 score is:  0.48
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  16 The model performance very well
# At random state:  16
# Test R2 score is:  0.48
# Train R2 score is:  0.48
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  35 The model performance very well
# At random state:  35
# Test R2 score is:  0.48
# Train R2 score is:  0.48
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  47 The model performance very well
# At random state:  47
# Test R2 score is:  0.48
# Train R2 score is:  0.48
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# At random state  58 The model performance very well
# At random state:  58
# ...

# %%
x_train,x_test,y_train,y_test= train_test_split(X,Y,random_state=150,test_size=.2)
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import SGDRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
LR_model= LinearRegression()
RD_model= Ridge()
LS_model= Lasso()
DT_model= DecisionTreeRegressor()
SV_model= SVR()
KNR_model= KNeighborsRegressor()
RFR_model= RandomForestRegressor()
Elastic_model= ElasticNet()
SGH_model= SGDRegressor()
Bag_model=BaggingRegressor()
ADA_model=AdaBoostRegressor()
GB_model= GradientBoostingRegressor()

model=[LR_model,RD_model,LS_model,DT_model,SV_model,KNR_model,RFR_model,Elastic_model,SGH_model,Bag_model,ADA_model,GB_model ]

# %%
for m in model:
    m.fit(x_train,y_train)
    print('mean_absolute_error of ',m ,'model', mean_absolute_error(y_test,m.predict(x_test)))
    print('mean_square_error of',m,'model' , mean_squared_error(y_test,m.predict(x_test)))
    print('R2 Score of',m,'model', r2_score(y_test,m.predict(x_test) )*100)
    print('X' * 50, '\n\n')
# Out:
# mean_absolute_error of  LinearRegression() model 0.21884879830508774
# mean_square_error of LinearRegression() model 0.07826082038095199
# R2 Score of LinearRegression() model 47.42447505071754
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
#
# mean_absolute_error of  Ridge() model 0.21884804603292085
# mean_square_error of Ridge() model 0.07826090806411941
# R2 Score of Ridge() model 47.424416145271195
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
#
# mean_absolute_error of  Lasso() model 0.31285141558819773
# mean_square_error of Lasso() model 0.1491756521908181
# R2 Score of Lasso() model -0.2160236170071661
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
#
# mean_absolute_error of  DecisionTreeRegressor() model 0.14612574341546306
# mean_square_error of DecisionTreeRegressor() model 0.045973406966864916
# R2 Score of DecisionTreeRegressor() model 69.11512052615517
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
#
# ...

# %% [markdown]
# # CROSS Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
for i in model:
    print('mean_square of ',i, 'model',mean_squared_error(y_test,i.predict(x_test)))
    print("cross Validation score of ",i ," is ",cross_val_score(i,X,Y,cv=5, scoring='neg_mean_squared_error').mean())
    print('*'*50)
# Out:
# mean_square of  LinearRegression() model 0.07826082038095199
# cross Validation score of  LinearRegression()  is  -0.08627158721588454
# **************************************************
# mean_square of  Ridge() model 0.07826090806411941
# cross Validation score of  Ridge()  is  -0.08627058049998507
# **************************************************
# mean_square of  Lasso() model 0.1491756521908181
# cross Validation score of  Lasso()  is  -0.1757734251910985
# **************************************************
# mean_square of  DecisionTreeRegressor() model 0.045973406966864916
# cross Validation score of  DecisionTreeRegressor()  is  -0.12493620287169167
# **************************************************
# mean_square of  SVR() model 0.03756247079360575
# cross Validation score of  SVR()  is  -0.08509595612110696
# **************************************************
# mean_square of  KNeighborsRegressor() model 0.040277683375814215
# ...

# %% [markdown]
# # Based on comparing Accuracy Score results with Cross Validation results, it is determined that Random Forest Regressor is the best model. It also has the lowest Root Mean Squared Error score

# %% [markdown]
# # Hyper Parameter Tuning

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.model_selection import GridSearchCV

# %%
# hyperparameter tuning for random forest
params_rf = {
    'n_estimators': [20,40,60,80],
    'min_samples_split':[4,6,8],
    'max_depth': [1, 5, 10, 15],
    'max_features': ['sqrt', 'auto','log2']
            }

# %%
grid_rf = GridSearchCV(rfc, params_rf, cv=5)

# %%
grid_rf.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [1, 5, 10, 15],
#                          'max_features': ['sqrt', 'auto', 'log2'],
#                          'min_samples_split': [4, 6, 8],
#                          'n_estimators': [20, 40, 60, 80]})

# %%
grid_rf.best_params_
# Out:
# {'max_depth': 15,
#  'max_features': 'auto',
#  'min_samples_split': 4,
#  'n_estimators': 60}

# %%
Finalmod = RandomForestRegressor(max_depth=15,max_features='auto',min_samples_split=4,n_estimators=60)
Finalmod.fit(x_train,y_train)
pred_final=Finalmod.predict(x_test)
rfs=r2_score(y_test,pred_final)
print('R2 Score', rfs*100)
# Out:
# R2 Score 83.85942714669702

# %% [markdown]
# # Saving model in pickle format

# %%
import joblib
joblib.dump(Finalmod,"Avacado.pkl")
# Out:
# ['Avacado.pkl']
